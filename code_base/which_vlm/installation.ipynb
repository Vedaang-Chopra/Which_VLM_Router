# %%
# ! uv pip install datasets --upgrade --quiet
# ! uv pip install jupyter ipywidgets --upgrade --quiet
# ! uv pip install pillow

# %%
# ! pip install \
#   "datasets[vision]" \
#   pyarrow \
#   pandas \
#   pillow \
#   jupyterlab \
#   ipykernel

# %%
# ! pip install --upgrade pip
